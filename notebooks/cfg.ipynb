# %%
import networkx as nx
import matplotlib.pylab as plt

g = nx.read_gml('../data/droidkungfu_w_benign/0_app_fileman/cg/benign.gml')

print(g.nodes(data=True))
# Out:
# [('Lbander/fileman/FileUtils;-><init>()V [access_flags=public constructor] @ 0x2070', {'external': 0, 'entrypoint': 0}), ('Ljava/lang/Object;-><init>()V', {'external': 1, 'entrypoint': 0}), ('Lbander/fileman/FileUtils;->copyFile(Ljava/io/File; Ljava/io/File;)Ljava/lang/Boolean; [access_flags=public static] @ 0x2088', {'external': 0, 'entrypoint': 0}), ('Ljava/io/FileInputStream;-><init>(Ljava/io/File;)V', {'external': 1, 'entrypoint': 0}), ('Ljava/io/FileOutputStream;->getChannel()Ljava/nio/channels/FileChannel;', {'external': 1, 'entrypoint': 0}), ('Ljava/io/FileInputStream;->getChannel()Ljava/nio/channels/FileChannel;', {'external': 1, 'entrypoint': 0}), ('Ljava/nio/channels/FileChannel;->size()J', {'external': 1, 'entrypoint': 0}), ('Ljava/nio/channels/FileChannel;->close()V', {'external': 1, 'entrypoint': 0}), ('Ljava/io/File;->exists()Z', {'external': 1, 'entrypoint': 0}), ('Ljava/lang/Boolean;->valueOf(Z)Ljava/lang/Boolean;', {'external': 1, 'entrypoint': 0}), ('Ljava/io/FileOu
# ...
